# %% [markdown]
# <a href="https://colab.research.google.com/github/KaduMelo/imersao-dados/blob/aula_2/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
fonte = 'https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true'

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
dados.shape
# Out:
# (127380, 136)

# %%
dados['SG_UF_RESIDENCIA']
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
dados[['SG_UF_RESIDENCIA', 'Q025']]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
len(dados['SG_UF_RESIDENCIA'].unique())
# Out:
# 27

# %%
dados['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
dados['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados['NU_IDADE'].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
dados['NU_IDADE'].hist()

# %%
dados['NU_IDADE'].hist(bins = 20, figsize = (10, 8))

# %% [markdown]
# Desafio01: Proporção dos inscritos por idade

# %%
total = len(dados['NU_IDADE'])
total_por_idade = dados['NU_IDADE'].value_counts()
porcentual = (100 * total_por_idade) / total
porcentual
# Out:
# 18    16.840948
# 17    16.687078
# 19    11.318888
# 20     8.174753
# 16     6.146962
#         ...
# 75     0.001570
# 73     0.001570
# 82     0.000785
# 77     0.000785
# 76     0.000785
# Name: NU_IDADE, Length: 65, dtype: float64

# %% [markdown]
# Desafio02: Descobrir de quais estados são os inscritos com 13 anos

# %%
dados.query('NU_IDADE == 13')['SG_UF_RESIDENCIA'].value_counts().sort_index()
# Out:
# AP    1
# BA    1
# MT    1
# SP    1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %% [markdown]
# Desafio03: Adicionar título no gráfico

# %%
dados['NU_IDADE'].plot.hist(bins = 20, figsize = (10, 8), grid=True, title="Histograma por idade")

# %% [markdown]
# Desafio04: Plotar os Histogramas das idades dos treineiros e não treineiros

# %%
import matplotlib.pyplot as plt

dados_treineiros = dados.query('TP_LINGUA == 0')['NU_NOTA_LC'].hist(bins=20, figsize=(7,5))
dados_nao_treineiros = dados.query('TP_LINGUA == 1')['NU_NOTA_LC'].hist(bins=20, figsize=(7,5), alpha=0.6)

plt.title("Histograma das línguas inglesa e espanhol no ENEM")
plt.legend(['Inglês', 'Espanhol'])

# %% [markdown]
# Desafio05: Comparar as distribuições das provas em inglês e espanhol

# %%
import matplotlib.pyplot as plt

dados_ingles = dados.query('IN_TREINEIRO == 1')['NU_IDADE'].hist(bins=20, figsize=(7,5))
dados_espanhol = dados.query('IN_TREINEIRO == 0')['NU_IDADE'].hist(bins=20, figsize=(7,5), alpha=0.6)

plt.title("Histograma das idades dos treineiros e não treineiros")
plt.legend(['Treineiros', 'Não treineiros'])

# %%
dados.query('IN_TREINEIRO == 1')
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0       190001004661    2019                  1506138  ...    A     B    B
# 4       190001004776    2019                  1500800  ...    A     A    B
# 12      190001005076    2019                  1506138  ...    A     A    B
# 14      190001005081    2019                  1506807  ...    A     A    B
# 16      190001005202    2019                  1502301  ...    A     A    A
# ...              ...     ...                      ...  ...  ...   ...  ...
# 127328  190006117441    2019                  3126752  ...    A     A    B
# 127340  190006117776    2019                  4305108  ...    A     C    B
# 127349  190006118483    2019                  2511301  ...    A     A    A
# 127350  190006118551    2019                  2611606  ...    B     B    B
# 127352  190006118561    2019                  2600807  ...    A     A    B
#
# [15401 rows x 136 columns]

# %%
dados.query('IN_TREINEIRO == 1')['NU_IDADE'].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
dados['NU_NOTA_REDACAO'].hist(bins = 20, figsize = (8,6))

# %%
dados['NU_NOTA_REDACAO'].mean()
# Out:
# 571.5700253970197

# %%
provas = ['NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_MT','NU_NOTA_LC','NU_NOTA_REDACAO']

dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_MT    NU_NOTA_LC  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  92758.000000  98043.000000     98043.000000
# mean     477.964015    507.365912    523.555206    520.463928       571.570025
# std       76.296099     82.972839    109.416939     64.556578       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    435.300000    483.700000       480.000000
# 50%      470.200000    510.900000    501.600000    526.100000       580.000000
# 75%      533.300000    567.100000    598.200000    565.100000       680.000000
# max      797.300000    809.400000    985.000000    801.700000      1000.000000

# %%
dados['NU_NOTA_LC'].plot.box(grid = True, figsize=(8,6))

# %%
dados[provas].boxplot(grid = True, figsize=(10,8))

# %% [markdown]
# # Aulas 2

# %%
dados.query("NU_IDADE == 13")
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 57359   190003297248    2019                  3504107  ...    B     B    B
# 95630   190004825557    2019                  5107602  ...    A     A    B
# 98197   190004926952    2019                  1600303  ...    A     B    B
# 116501  190005659236    2019                  2917508  ...    B     C    B
#
# [4 rows x 136 columns]

# %%
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# SP    0.075862
# MG    0.075862
# MA    0.062069
# GO    0.048276
# PI    0.048276
# PB    0.048276
# AM    0.027586
# MT    0.027586
# DF    0.027586
# SE    0.020690
# TO    0.020690
# PR    0.020690
# SC    0.013793
# RO    0.013793
# AL    0.013793
# AP    0.006897
# ES    0.006897
# RN    0.006897
# MS    0.006897
# RJ    0.006897
# AC    0.006897
# RS    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
alunos_menor_quartoze = dados.query("NU_IDADE <= 14")
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts().plot.pie(figsize=(10,8))

# %%
alunos_menor_quartoze["SG_UF_RESIDENCIA"].value_counts().plot.bar(figsize=(10,8))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

renda_ordenada = dados['Q006'].unique()
renda_ordenada.sort()

plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y = "NU_NOTA_MT", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas de matemáticas pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemáticas pela renda')

# %% [markdown]
# MEGA DESAFIO DA THAINÁ 1: Pegar a amostra completa dos alunos de 13 e 14 anos
#
# Desafio 4: Verificar se quem zerou a prova foi eliminado ou não estava presente
#
# Desafio 5: Quem é elminado tira zero ou será NAN (não teve registro de notas)
#
# Desafio 6: Verificar a proporção dos participantes de rendas mais altas e mais baixas como treineiros e não treineiros

# %% [markdown]
# Desafio 3: Criar uma função para plotar o boxplot do seaborn

# %%
def boxplot_seaborn(title, eixo_x, eixo_y, dados, **kwargs):
  plt.figure(figsize=(10,8))
  sns.boxplot(x=eixo_x, y = eixo_y, data = dados, **kwargs)
  plt.title(title)

# %%
dados[provas].sum()
# Out:
# NU_NOTA_CN         44334986.1
# NU_NOTA_CH         49743676.1
# NU_NOTA_MT         48563933.8
# NU_NOTA_LC         51027844.9
# NU_NOTA_REDACAO    56038440.0
# dtype: float64

# %%
dados[provas].sum(axis=1)
# Out:
# 0         2288.9
# 1         1184.6
# 2         2350.5
# 3         2555.7
# 4         2803.5
#            ...
# 127375    2867.4
# 127376    2218.5
# 127377    1453.9
# 127378    2573.9
# 127379    2287.8
# Length: 127380, dtype: float64

# %%
dados['NU_NOTA_TOTAL'] = dados[provas].sum(axis=1)
dados.head()

# plt.figure(figsize=(10,8))
# sns.boxplot(x="Q006", y = "NU_NOTA_TOTAL", data = dados, order = renda_ordenada)
# plt.title("Boxplot das notas de total pela renda")

boxplot_seaborn("Boxplot das notas de total pela renda", "Q006", "NU_NOTA_TOTAL", dados, order = renda_ordenada)

# %%
sns.displot(dados, x = 'NU_NOTA_TOTAL')

# %%
dados.query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_INSCRICAO  NU_ANO  ...  Q025 NU_NOTA_TOTAL
# 10      190001005028    2019  ...     A           0.0
# 11      190001005057    2019  ...     B           0.0
# 26      190001005484    2019  ...     B           0.0
# 38      190001006086    2019  ...     B           0.0
# 40      190001006292    2019  ...     B           0.0
# ...              ...     ...  ...   ...           ...
# 127351  190006118552    2019  ...     B           0.0
# 127365  190006119756    2019  ...     A           0.0
# 127366  190006119783    2019  ...     A           0.0
# 127368  190006119802    2019  ...     B           0.0
# 127374  190006119995    2019  ...     B           0.0
#
# [29162 rows x 137 columns]

# %%
provas.append("NU_NOTA_TOTAL")

# %%
provas = ['NU_NOTA_CN',
 'NU_NOTA_CH',
 'NU_NOTA_MT',
 'NU_NOTA_LC',
 'NU_NOTA_REDACAO',
 'NU_NOTA_TOTAL']

# %%
dados_sem_notas_zeros = dados.query('NU_NOTA_TOTAL != 0')
dados_sem_notas_zeros.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
# plt.figure(figsize=(10,8))
# sns.boxplot(x="Q006", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zeros, order = renda_ordenada)
# plt.title("Boxplot das notas de total pela renda")

boxplot_seaborn("Boxplot das notas de total pela renda", "Q006", "NU_NOTA_TOTAL", dados_sem_notas_zeros, order = renda_ordenada)

# %%
# plt.figure(figsize=(10,8))
# sns.boxplot(x="Q006", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zeros, hue="IN_TREINEIRO", order = renda_ordenada)
# plt.title("Boxplot das notas de total pela renda")


boxplot_seaborn("Boxplot das notas de total pela renda", "Q006", "NU_NOTA_TOTAL", dados_sem_notas_zeros, hue="IN_TREINEIRO", order = renda_ordenada)

# %% [markdown]
# Desafio 7: Fazer o mesmo boxplot olhando para a questão 25 (tem internet ou não) e fazer uma reflexão sobre o assunto e o contexto de pandemia

# %%
# boxplot_seaborn("Boxplot das notas de total pelas pessoas que tem internet e não tem", "Q025", "NU_NOTA_TOTAL", dados_sem_notas_zeros, hue="Q025")
plt.figure(figsize=(10,8))
sns.boxplot(x="Q025", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zeros, hue="Q025", labels=['Internet', 'Sem internet'])
plt.title("Boxplot das notas de total pelas pessoas que tem internet e não tem")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-754354e6febc> in <module>()
#       1 # boxplot_seaborn("Boxplot das notas de total pelas pessoas que tem internet e não tem", "Q025", "NU_NOTA_TOTAL", dados_sem_notas_zeros, hue="Q025")
#       2 plt.figure(figsize=(10,8))
# ----> 3 sns.boxplot(x="Q025", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zeros, hue="Q025", labels=['Internet', 'Sem internet'])
#       4 plt.title("Boxplot das notas de total pelas pessoas que tem internet e não tem")
#
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
